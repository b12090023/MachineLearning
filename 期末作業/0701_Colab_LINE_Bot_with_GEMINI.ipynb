# %%
# !pip install Flask pyngrok line-bot-sdk requests --quiet
# !pip install google-genai --quiet

# %%
from google.colab import userdata

ngrok_authtoken = userdata.get('NGROK_AUTHTOKEN')
line_channel_access_token = userdata.get('LINE_CHANNEL_ACCESS_TOKEN')
line_channel_secret = userdata.get('LINE_CHANNEL_SECRET')
gemini_api_key = userdata.get('GEMINI_API_KEY')
port = 5051

# %%
import os
from pyngrok import ngrok

# %%
ngrok.kill()

# %%
import requests

ngrok.set_auth_token(ngrok_authtoken)
tunnel = ngrok.connect(5051, name="linebot_tunnel")
webhook_url = tunnel.public_url

print(f"Ngrok URL: {webhook_url}")

# 自動更新 LINE Webhook URL
def update_line_webhook(webhook_url):
    """使用 LINE Messaging API 更新 Webhook URL"""
    url = "https://api.line.me/v2/bot/channel/webhook/endpoint"
    headers = {
        "Authorization": f"Bearer {line_channel_access_token}",
        "Content-Type": "application/json"
    }
    data = {
        "endpoint": webhook_url
    }

    response = requests.put(url, headers=headers, json=data)

    if response.status_code == 200:
        print(f"✅ LINE Webhook URL 已自動更新為：{webhook_url}")
        return True
    else:
        print(f"❌ 更新失敗：{response.status_code} - {response.text}")
        return False

# 執行更新
update_line_webhook(webhook_url)
# Out:
# Ngrok URL: https://customize-watch-lifting.ngrok-free.dev
# ✅ LINE Webhook URL 已自動更新為：https://customize-watch-lifting.ngrok-free.dev
# True

# %%
from google import genai

client = genai.Client(api_key=gemini_api_key)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="什麼是AI AGENT？"
)
print(response.text)
# Out:
# AI Agent（人工智慧代理人）是一種能夠**感知**其環境，並根據這些感知**做出決策**，最終**採取行動**以達成特定目標的**智慧實體或系統**。
#
# 你可以把AI Agent想像成一個「數位管家」或「機器人」，它被設計來代表某人或某個系統，在特定的環境中執行任務。
#
# **主要特徵：**
#
# 1.  **感知能力 (Perception)：**
#     *   Agent 必須能夠從其環境中獲取資訊。這可以是透過感測器（如攝影機、麥克風、溫度計等）來感知物理世界，或是透過接收數據、讀取檔案、監聽網路事件等方式來感知數位世界。
#
# 2.  **決策能力 (Decision-Making)：**
#     *   Agent 會根據其感知到的資訊，並結合內建的知識庫、規則、演算法（如機器學習模型）來分析情況，並決定下一步的最佳行動。
#
# 3.  **行動能力 (Action)：**
#     *   Agent 能夠在其環境中執行動作。這可以是物理上的動作（如移動機器人手臂、駕駛汽車），也可以是數位上的動作（如發送電子郵件、更新資料庫、執行程式碼、生成文字）。
#
# 4.  **自主性 (Autonomy)：**
#     *   Agent 能夠在一定程度上獨立運作，無需人類每一步的指示。它會根據預設的目標和策略自行做出決策並採取行動。
#
# 5.  **目標導向 (Goal-Oriented)：**
#     *   Agent 的所有行為都圍繞著實現一個或多個特定目標。例如，一個導航Agent的目標是將你帶到目的地，一個推薦Agent的目標是提供你可能喜歡的內容。
#
# **AI Agent 的運作流程可以簡化為一個循環：**
#
# **感知 (Perceive) → 思考/決策 (Think/Decide) → 行動 (Act) → 循環 (Repeat)**
#
# **常見範例：**
#
# *   **虛擬助理/聊天機器人 (Virtual Assistants/Chatbots)：** 如Siri、Alexa、Google Assistant。它們感知你的語音指令或文字輸入，決策如何回應，並採取行動（播放音樂、回答問題、設置鬧鐘等）。
# *   **自動駕駛汽車 (Self-driving Cars)：** 感知周圍環境（其他車輛、行人、交通號誌），決策行駛路線和速度，並控制方向盤、油門、剎車來行駛。
# *   **推薦系統 (Recommendation Systems)：** 如Netflix、Amazon。感知你的觀看或購買歷史，決策你可能喜歡的商品或內容，並將其推薦給你。
# *   **遊戲中的非玩家角色 (NPCs in Games)：** 感知遊戲世界狀態，決策自己的行為（攻擊、防禦、移動），並在遊戲中執行這些動作。
# *   **工業機器人 (Industrial Robots)：** 感知工件位置，決策抓取或組裝步驟，並透過機械手臂完成任務。
# *   **智慧家居設備 (Smart Home Devices)：** 如智慧恆溫器感知室內溫度，決策是否開啟空調或暖氣。
#
# **AI Agent 與「AI」的關係：**
#
# 「AI」是一個廣泛的領域，包含了各種理論、技術和方法。而「AI Agent」則可以看作是AI應用的一種具體形式，它利用了AI領域的技術（如機器學習、自然語言處理、電腦視覺等），來建立一個能夠與環境互動並實現目標的**獨立實體**。
#
# 總之，AI Agent是人工智慧的核心概念之一，它提供了一個框架，讓我們能夠設計和實現能夠理解、思考並在現實或虛擬世界中採取行動的智慧系統。

# %%
def stateless_query(payload):
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=payload
    )
    return response.text

# %%
result = stateless_query("簡介明新科技大學")
print(result)
# Out:
# 明新科技大學（簡稱明新科大）是一所位於台灣新竹縣新豐鄉的私立科技大學。
#
# **簡要介紹：**
#
# 1.  **歷史沿革：** 學校創立於1966年，前身為「明新工業專科學校」，於2000年改制為「明新科技大學」，擁有超過半世紀的辦學歷史。
#
# 2.  **地理位置：** 明新科大地理位置優越，鄰近新竹科學園區，這為學校與周邊高科技產業的合作以及學生的實習和就業提供了極佳的機會。
#
# 3.  **教學特色：**
#     *   **實務導向：** 學校以「誠、信、精、勤」為校訓，強調理論與實務並重，致力於培育具備專業知識與實作能力的科技人才。
#     *   **產學合作：** 積極推動產學合作，與眾多企業建立夥伴關係，提供學生豐富的實習機會，並將產業趨勢融入課程設計，以提升學生的職場競爭力。
#     *   **高就業率：** 明新科大以其高畢業生就業率而聞名，許多校友在各行各業表現傑出。
#
# 4.  **學院設置：** 目前學校設有四大教學單位，提供多元的學術領域和課程：
#     *   **工學院：** 涵蓋工程技術領域。
#     *   **管理學院：** 培養管理與商業人才。
#     *   **服務事業學院：** 專注於觀光、餐飲、幼保等服務產業。
#     *   **設計學院：** 發展數位媒體設計、空間設計等專業。
#
# **總結來說，** 明新科技大學是一所強調實務教學、密切與產業結合、並以高就業率為特色的科技大學，致力於為社會培養具備專業技能與良好品格的應用型人才。

# %%
from flask import Flask, request, abort

from linebot.v3 import (
    WebhookHandler
)
from linebot.v3.exceptions import (
    InvalidSignatureError
)
from linebot.v3.messaging import (
    Configuration,
    ApiClient,
    MessagingApi,
    ReplyMessageRequest,
    TextMessage,
)
from linebot.v3.webhooks import (
    MessageEvent,
    TextMessageContent,
)

app = Flask(__name__)

configuration = Configuration(access_token=line_channel_access_token)
handler = WebhookHandler(line_channel_secret)


@app.route("/", methods=['POST'])
def callback():
    # get X-Line-Signature header value
    signature = request.headers['X-Line-Signature']

    # get request body as text
    body = request.get_data(as_text=True)
    print("BODY: ", body)
    app.logger.info("Request body: " + body)

    # handle webhook body
    try:
        handler.handle(body, signature)
    except InvalidSignatureError:
        app.logger.info("Invalid signature. Please check your channel access token/channel secret.")
        abort(400)

    return 'OK'


@handler.add(MessageEvent, message=TextMessageContent)
def handle_message(event):
    text = event.message.text
    with ApiClient(configuration) as api_client:
        line_bot_api = MessagingApi(api_client)
        if text.startswith('AI '):     #有設定限定AI 開頭的才會用Gemini
            prompt = text[3:]
            reply_text = stateless_query(prompt)
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text=reply_text)]
                )
            )

        else:
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text=event.message.text),
                        TextMessage(text=event.message.text)]
                )
            )

if __name__ == "__main__":
    app.run(port=port)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5051
# INFO:werkzeug:Press CTRL+C to quit
# BODY:  {"destination":"Ub9ff2c3714925949563d00e62be17749","events":[{"type":"message","message":{"type":"text","id":"615029934700101839","quoteToken":"rOH8aorqb3feTec2i9T7h27SJKld7BLddxDscsU7RkMi1YDy6itMq-UBnD6QlHxAwkiTqLombICKssYFt2fGJM1qIKUdS5qbwt0yjR3UPYbfI4dOgqsovIQjdDZWwyRf1OP213_ohUbx8EbGfI5qBA","markAsReadToken":"ENIAwn_M4uZ6lsQVNxIlKti2aw62Cq9TYoJX0TZKXGXAFoRqMGNc1pcvX39LISAvLPWFhJnDzl23e3qxXQhohcP3bShWyMHclAzCaF3p3qA8iE9bGuH7wtXY_cGcFp2TOhSxV2JmvAJcqZosuxPdOffgdyQEA8Xbh0TnX4C79sQ-3get2cwaHlnszn8kaWRsYcfWSTQ2PsREkibwKzEQLg","text":"AI 簡介明新科技大學"},"webhookEventId":"01KS6RZ1CP1849DEHPJPD7PASB","deliveryContext":{"isRedelivery":false},"timestamp":1779417711947,"source":{"type":"user","userId":"U913e7b32d982838f15ac288880e33797"},"replyToken":"4208bd47e02049488091bc42d7d74b40","mode":"active"}]}
# INFO:werkzeug:127.0.0.1 - - [22/May/2026 02:42:03] "POST / HTTP/1.1" 200 -
